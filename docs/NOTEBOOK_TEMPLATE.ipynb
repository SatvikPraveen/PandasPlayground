# %% [markdown]
# # 📓 Notebook XX: [Topic Name]
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - ✅ Objective 1: Describe what you'll learn
# - ✅ Objective 2: Another skill or concept
# - ✅ Objective 3: Practical application
# - ✅ Objective 4: Advanced technique (if applicable)
#
# **Estimated Time:** XX minutes
#
# **Prerequisites:**
# - Basic Python knowledge
# - Familiarity with pandas basics (if advanced notebook)
# - Completion of notebooks 01-XX (if sequential)
#
# ---

# %% [markdown]
# ## 📦 Setup & Imports
#
# First, let's import the libraries we'll need for this notebook.

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Custom utilities
import sys
sys.path.append('..')
from scripts import utils_io, cleaning_utils, agg_utils

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
plt.style.use('seaborn-v0_8-darkgrid')

# Verify versions
print(f"📊 Pandas version: {pd.__version__}")
print(f"🔢 NumPy version: {np.__version__}")

# %% [markdown]
# ---
#
# ## 📥 Load Data
#
# Load the dataset we'll be working with in this notebook.

# %%
# Load your dataset
df = utils_io.load_csv('../data/your_dataset.csv')

# Quick inspection
print(f"📊 Dataset shape: {df.shape}")
print(f"🔸 Columns: {list(df.columns)}")
df.head()

# %% [markdown]
# ---
#
# ## 🔍 Section 1: [Concept Name]
#
# ### Theory
#
# Brief explanation of the concept we're about to demonstrate.
#
# **Key Points:**
# - Point 1
# - Point 2
# - Point 3
#
# ### Practice

# %%
# Example code with clear comments
result = df.groupby('column').agg({'value': 'sum'})
result

# %% [markdown]
# **💡 What just happened?**
#
# Explain the output and what the code accomplished.
#
# **🎯 Common Pitfalls:**
# - Pitfall 1: Description
# - Pitfall 2: Description

# %% [markdown]
# ### ✏️ Exercise 1.1
#
# **Task:** Brief description of what to do
#
# **Hints:**
# - Hint 1
# - Hint 2

# %%
# Your code here

# %% [markdown]
# <details>
# <summary><b>💡 Solution (Click to reveal)</b></summary>
#
# ```python
# # Solution code
# solution = df.example_method()
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🔍 Section 2: [Another Concept]
#
# Continue with more sections as needed...

# %% [markdown]
# ---
#
# ## 📊 Real-World Application
#
# Let's apply what we've learned to a practical scenario.
#
# **Scenario:** Describe a real-world use case

# %%
# Real-world example

# %% [markdown]
# ---
#
# ## 💾 Save Results
#
# Export our processed data for use in later notebooks.

# %%
# Save processed data
utils_io.save_csv(result, '../assets/processed_data.csv')
print("✅ Data saved successfully!")

# %% [markdown]
# ---
#
# ## 📚 Summary
#
# ### What We Learned
#
# In this notebook, we covered:
#
# 1. **Concept 1:** Brief recap
# 2. **Concept 2:** Brief recap
# 3. **Concept 3:** Brief recap
# 4. **Practical Application:** Real-world use case
#
# ### Key Takeaways
#
# - 🔑 Takeaway 1
# - 🔑 Takeaway 2
# - 🔑 Takeaway 3
#
# ### Common Mistakes to Avoid
#
# - ❌ Mistake 1
# - ❌ Mistake 2
# - ❌ Mistake 3
#
# ---

# %% [markdown]
# ## 🎯 Practice Challenges
#
# Test your understanding with these challenges:
#
# ### Challenge 1: Easy
# **Task:** Description
#
# ### Challenge 2: Medium
# **Task:** Description
#
# ### Challenge 3: Hard
# **Task:** Description
#
# 💡 **Solutions available in `docs/solutions/notebook_XX_solutions.md`**

# %% [markdown]
# ---
#
# ## 📖 Additional Resources
#
# Want to learn more? Check out:
#
# - [Pandas Documentation - Topic](https://pandas.pydata.org/docs/...)
# - [Stack Overflow - Common Questions](https://stackoverflow.com/...)
# - [Related Blog Post](https://...)
#
# ---

# %% [markdown]
# ## ➡️ Next Steps
#
# Ready to move forward? Continue to:
#
# - **Next Notebook:** `XX_next_topic.ipynb` - Brief description
# - **Related Notebook:** `YY_related_topic.ipynb` - Brief description
#
# Or explore:
# - 📊 Try the Streamlit dashboard: `streamlit run STREAMLIT_App.py`
# - 🧪 Review the test suite: `pytest scripts/test_utils.py -v`
# - 📚 Check the cheatsheet: `cheatsheets/pandas_cheatsheet.md`
#
# ---
#
# ## 💬 Feedback
#
# Found an error or have suggestions? Please:
# - Open an [issue on GitHub](https://github.com/SatvikPraveen/PandasPlayground/issues)
# - Submit a [pull request](https://github.com/SatvikPraveen/PandasPlayground/pulls)
#
# ---
#
# **Happy Learning! 🎓**
