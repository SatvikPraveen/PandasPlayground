# %% [markdown]
# # 🧩 Notebook 09: Professional Reporting & Exporting Techniques in pandas

# %%
# Notebook import setup
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from scripts import utils_io

# %% [markdown]
# ## 🧭 1. Setup & Dataset Load

# %%
# 📦 Imports
import pandas as pd
from scripts import utils_io

# 📂 Load final dataset from previous pipeline
df = utils_io.load_csv("../exports/final_merged_pipeline.csv")

# 🖼️ Preview
df.head()
# Out:
#      month     sales   profit  new_cases  hospitalized  rolling_profit  \
# 0  2020-01  36627.07  1490.90      15558   2171.483871             NaN
# 1  2020-02  26120.18  1775.53      14543   2458.517241             NaN
# 2  2020-03  33591.53  1297.55      15392   2630.225806     1521.326667
# 3  2020-04  24267.89  1186.19      15148   2560.866667     1419.756667
# 4  2020-05  30944.10  1753.54      15542   2170.387097     1412.426667
#
#    sales_pct_change
# 0               NaN
# 1         -0.286861
# 2          0.286037
# 3         -0.277559
# 4          0.275105

# %% [markdown]
# ## 📤 2. Exporting Data

# %%
# ✅ Export to CSV
utils_io.export_csv(df, "../exports/report_final.csv")

# ✅ Export to Excel
utils_io.export_excel(df, "../exports/report_final.xlsx")

# ✅ Export to Parquet
df.to_parquet("../exports/report_final.parquet", index=False)
# Out:
# ✅ Exported CSV to: ../exports/report_final.csv
# ✅ Exported Excel to: ../exports/report_final.xlsx

# %% [markdown]
# ## 🎨 3. Styling Reports with .style

# %%
# 🎨 Apply pandas styling
styled_df = (
    df.style
    .background_gradient(subset=["sales", "profit"], cmap="Greens")
    .format({"sales": "${:,.2f}", "profit": "${:,.2f}"})
    .highlight_max(color="lightblue", axis=0)
)

# 👀 Display styled DataFrame (Notebook-only preview)
styled_df
# Out:
# <style type="text/css">
# #T_43e45_row0_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_43e45_row0_col2, #T_43e45_row34_col2, #T_43e45_row36_col2, #T_43e45_row247_col2, #T_43e45_row282_col1, #T_43e45_row326_col2 {
#   background-color: #97d492;
#   color: #000000;
# }
# #T_43e45_row1_col1, #T_43e45_row18_col2, #T_43e45_row63_col2, #T_43e45_row107_col2, #T_43e45_row224_col2, #T_43e45_row296_col1 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_43e45_row1_col2, #T_43e45_row47_col1, #T_43e45_row54_col1, #T_43e45_row140_col2, #T_43e45_row185_col1, #T_43e45_row247_col1 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_43e45_row2_col1, #T_43e45_row86_col1 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_43e45_row2_col2, #T_43e45_row28_col2, #T_43e45_row50_col2 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_43e45_row3_col1, #T_43e45_row14_col2, #T_43e45_row186_col2 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_43e45_row3_col2, #T_43e45_row15_col2, #T_43e45_row23_col2, #T_43e45_row167_col2, #T_43e45_row174_col2 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_43e45_row4_col1, #T_43e45_row214_col1, #T_43e45_row322_col2 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_43e45_row4_col2, #T_43e45_row56_col1, #T_43e45_row97_col1, #T_43e45_row116_col1, #T_43e45_row278_col2 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_43e45_row5_col1, #T_43e45_row67_col1, #T_43e45_row67_col2, #T_43e45_row104_col1, #T_43e45_row180_col2, #T_43e45_row310_col2 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_43e45_row19_col2, #T_43e45_row164_col1, #T_43e45_row257_col2, #T_43e45_row325_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_43e45_row20_col2, #T_43e45_row289_col2 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_43e45_row21_col1, #T_43e45_row62_col2, #T_43e45_row197_col1, #T_43e45_row316_col1 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_43e45_row21_col2, #T_43e45_row22_col2, #T_43e45_row59_col1, #T_43e45_row69_col2, #T_43e45_row259_col2, #T_43e45_row268_col1, #T_43e45_row312_col1 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_43e45_row22_col1, #T_43e45_row64_col1, #T_43e45_row176_col1, #T_43e45_row233_col1, #T_43e45_row321_col2 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_43e45_row23_col1, #T_43e45_row45_col2, #T_43e45_row91_col2, #T_43e45_row132_col1, #T_43e45_row204_col1, #T_43e45_row236_col2 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_43e45_row24_col1, #T_43e45_row69_col1, #T_43e45_row84_col1, #T_43e45_row294_col2 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_43e45_row24_col2, #T_43e45_row44_col2, #T_43e45_row187_col2 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_43e45_row25_col1, #T_43e45_row56_col2, #T_43e45_row299_col1 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_43e45_row25_col2, #T_43e45_row104_col2, #T_43e45_row114_col2, #T_43e45_row189_col2, #T_43e45_row193_col2, #T_43e45_row194_col2, #T_43e45_row275_col2 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_43e45_row26_col1, #T_43e45_row55_col1, #T_43e45_row93_col1, #T_43e45_row103_col1, #T_43e45_row258_col1 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_43e45_row26_col2, #T_43e45_row196_col2 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_43e45_row27_col1, #T_43e45_row249_col1 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_43e45_row27_col2, #T_43e45_row39_col1, #T_43e45_row120_col1, #T_43e45_row243_col2 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_43e45_row28_col1, #T_43e45_row81_col1, #T_43e45_row113_col2, #T_43e45_row229_col2, #T_43e45_row232_col2, #T_43e45_row251_col2, #T_43e45_row288_col2, #T_43e45_row311_col2 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_43e45_row29_col1 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_43e45_row30_col1, #T_43e45_row46_col2, #T_43e45_row48_col1, #T_43e45_row174_col1, #T_43e45_row285_col2 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_43e45_row30_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_43e45_row31_col1, #T_43e45_row129_col1, #T_43e45_row206_col2, #T_43e45_row220_col1, #T_43e45_row300_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_43e45_row31_col2 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_43e45_row32_col1, #T_43e45_row143_col1, #T_43e45_row173_col1, #T_43e45_row198_col2, #T_43e45

# %% [markdown]
# ## 📦 4. Save Styled Report to Excel

# %%
# 💾 Export styled report to Excel
styled_df.to_excel("../exports/styled_report.xlsx", engine="openpyxl")

# %% [markdown]
# ## Reusable Styling Utility

# %%
# 🛠️ Usage
def my_style(df):
    return (
        df.style
        .format({"sales": "${:,.2f}", "profit": "${:,.2f}"})
        .highlight_max(color="lightblue", axis=0)
    )

utils_io.export_styled_excel(df, "../exports/final_custom_styled.xlsx", style_func=my_style)

# %% [markdown]
# ## 📌 Summary of Learnings
#
# - Exported data to **CSV**, **Excel**, and **Parquet** formats
# - Created **styled reports** using `.style` for professional output
# - Saved styled DataFrames as Excel files with formatting
# - Defined **reusable reporting utilities** for automation
# - This notebook completes the reporting stage of the pipeline
